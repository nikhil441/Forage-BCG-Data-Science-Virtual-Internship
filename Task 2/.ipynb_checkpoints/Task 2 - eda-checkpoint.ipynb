# %% [markdown]
# # Exploratory Data Analysis Starter
#
# ## Import packages

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Shows plots in jupyter notebook
# %matplotlib inline

# Set plot style
sns.set(color_codes=True)

# %% [markdown]
# ---
#
# ## Loading data with Pandas
#
# We need to load `client_data.csv` and `price_data.csv` into individual dataframes so that we can work with them in Python. For this notebook and all further notebooks, it will be assumed that the CSV files will the placed in the same file location as the notebook. If they are not, please adjust the directory within the `read_csv` method accordingly.

# %%
client_df = pd.read_csv('./client_data.csv')
price_df = pd.read_csv('./price_data.csv')

# %% [markdown]
# You can view the first 3 rows of a dataframe using the `head` method. Similarly, if you wanted to see the last 3, you can use `tail(3)`

# %%
client_df.head(3)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# 0      2015-11-01   2015-06-23               0.00  ...        t       0.0
# 1      2009-08-21   2015-08-31             189.95  ...        f       0.0
# 2      2010-04-16   2015-04-17              47.96  ...        f       0.0
#
#    margin_gross_pow_ele  margin_net_pow_ele  nb_prod_act  net_margin  \
# ...

# %%
price_df.head(3)
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0

# %% [markdown]
# ---
#
# ## Descriptive statistics of data
#
# ### Data types
#
# It is useful to first understand the data that you're dealing with along with the data types of each column. The data types may dictate how you transform and engineer features.
#
# To get an overview of the data types within a data frame, use the `info()` method.

# %%
client_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
# ...

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  object
#  1   price_date          193002 non-null  object
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.8+ MB

# %% [markdown]
# ### Statistics
#
# Now let's look at some statistics about the datasets. We can do this by using the `describe()` method.

# %%
client_df.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %%
price_df.describe()
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# 25%             40.728885        0.000000            0.000000
# ...

# %% [markdown]
# ---
#
# ## Data visualization
#
# If you're working in Python, two of the most popular packages for visualization are `matplotlib` and `seaborn`. We highly recommend you use these, or at least be familiar with them because they are ubiquitous!
#
# Below are some functions that you can use to get started with visualizations.

# %%
def plot_stacked_bars(dataframe, title_, size_=(18, 10), rot_=0, legend_="upper right"):
    """
    Plot stacked bars with annotations
    """
    ax = dataframe.plot(
        kind="bar",
        stacked=True,
        figsize=size_,
        rot=rot_,
        title=title_
    )

    # Annotate bars
    annotate_stacked_bars(ax, textsize=14)
    # Rename legend
    plt.legend(["Retention", "Churn"], loc=legend_)
    # Labels
    plt.ylabel("Company base (%)")
    plt.show()

def annotate_stacked_bars(ax, pad=0.99, colour="white", textsize=13):
    """
    Add value annotations to the bars
    """

    # Iterate over the plotted rectanges/bars
    for p in ax.patches:
        
        # Calculate annotation
        value = str(round(p.get_height(),1))
        # If value is 0 do not annotate
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad),
            color=colour,
            size=textsize
        )

def plot_distribution(dataframe, column, ax, bins_=50):
    """
    Plot variable distirbution in a stacked histogram of churned or retained company
    """
    # Create a temporal dataframe with the data to be plot
    temp = pd.DataFrame({"Retention": dataframe[dataframe["churn"]==0][column],
    "Churn":dataframe[dataframe["churn"]==1][column]})
    # Plot the histogram
    temp[["Retention","Churn"]].plot(kind='hist', bins=bins_, ax=ax, stacked=True)
    # X-axis label
    ax.set_xlabel(column)
    # Change the x-axis to plain style
    ax.ticklabel_format(style='plain', axis='x')

# %% [markdown]
# Thhe first function `plot_stacked_bars` is used to plot a stacked bar chart. An example of how you could use this is shown below:

# %%
churn = client_df[['id', 'churn']]
churn.columns = ['Companies', 'churn']
churn_total = churn.groupby(churn['churn']).count()
churn_percentage = churn_total / churn_total.sum() * 100
plot_stacked_bars(churn_percentage.transpose(), "Churning status", (5, 5), legend_="lower right")

# %% [markdown]
# The second function `annotate_bars` is used by the first function, but the third function `plot_distribution` helps you to plot the distribution of a numeric column. An example of how it can be used is given below:

# %% [markdown]
# # Sales Channel

# %%
# Extract relevant columns from the client_df DataFrame
sales_data = client_df[['id', 'channel_sales', 'churn']]

# Group the data by sales channels and churn status, then count the occurrences
sales_channel_counts = sales_data.groupby(['channel_sales', 'churn'])['id'].count().unstack(level=1).fillna(0)

# Calculate the percentage of churn for each sales channel
channel_churn_percentage = (sales_channel_counts.div(sales_channel_counts.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

# Visualize the results using a stacked bar plot
plot_stacked_bars(channel_churn_percentage, 'Sales channel', rot_=30)

# %%
selected_columns = ['id', 'cons_12m', 'cons_gas_12m', 'cons_last_month', 'imp_cons', 'has_gas', 'churn']
consumption_data = client_df[selected_columns]

def plot_distribution(data, column, axes, bins_=50):
    """
    Plot variable distribution in a stacked histogram of churned or retained companies
    """
    # Create a temporary DataFrame with the data to be plotted
    temp_df = pd.DataFrame({
        "Retention": data[data["churn"] == 0][column],
        "Churn": data[data["churn"] == 1][column]
    })
    
    # Plot the histogram
    temp_df[["Retention", "Churn"]].plot(kind='hist', bins=bins_, ax=axes, stacked=True)
    
    # X-axis label
    axes.set_xlabel(column)
    
    # Change the x-axis to plain style
    axes.ticklabel_format(style='plain', axis='x')

# Create subplots
fig, axs = plt.subplots(nrows=4, figsize=(18, 25))

# Plot distributions for different columns
plot_distribution(consumption_data, 'cons_12m', axs[0])
plot_distribution(consumption_data[consumption_data['has_gas'] == 't'], 'cons_gas_12m', axs[1])
plot_distribution(consumption_data, 'cons_last_month', axs[2])
plot_distribution(consumption_data, 'imp_cons', axs[3])

# %% [markdown]
# The data related to consumption exhibits a considerable positive skewness, evident in the elongated right tail extending towards higher values within the distribution. The extremes of this distribution likely contain outliers. To gain a more detailed insight into these outliers, a conventional approach involves using a boxplot. This type of plot provides a standardized representation of the distribution, offering insights derived from a five-number summary:
#
# Minimum
# First quartile (Q1)
# Median
# Third quartile (Q3)
# Maximum
#
# By leveraging a boxplot, we can effectively identify outliers and discern their specific values. Furthermore, it enables us to evaluate the symmetry of our data, assess the tightness of data clustering, and ascertain any skewness present in the dataset.

# %%
# Create subplots
fig, axs = plt.subplots(nrows=4, figsize=(18, 25))

# Plot boxplots for consumption data
sns.boxplot(consumption["cons_12m"], ax=axs[0])
sns.boxplot(consumption[consumption["has_gas"] == "t"]["cons_gas_12m"], ax=axs[1])
sns.boxplot(consumption["cons_last_month"], ax=axs[2])
sns.boxplot(consumption["imp_cons"], ax=axs[3])

# Remove scientific notation and set x-axis limits
for ax in axs:
    ax.ticklabel_format(style='plain', axis='x')
    ax.set_xlim(-200000, 2000000)

# Display the plots
plt.show()
# Out:
# C:\Users\nikhi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\nikhi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\nikhi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# # Forecast

# %%
# Select relevant forecast columns from the client_df DataFrame
forecast_columns = ["forecast_cons_12m", "forecast_cons_year", "forecast_discount_energy",
                    "forecast_meter_rent_12m", "forecast_price_energy_off_peak",
                    "forecast_price_energy_peak", "forecast_price_pow_off_peak"]

forecast_data = client_df[forecast_columns]

# Create boxplots for each forecast column based on the churn status
for column in forecast_data:
    client_df.boxplot(column=column, by='churn', figsize=(6, 6))
    plt.title(column)

# Display the boxplots
plt.show()

# %%
# Create subplots for histograms
fig, axs = plt.subplots(nrows=7, figsize=(18, 50))

# Plot distributions for different forecast columns
plot_distribution(client_df, "forecast_cons_12m", axs[0])
plot_distribution(client_df, "forecast_cons_year", axs[1])
plot_distribution(client_df, "forecast_discount_energy", axs[2])
plot_distribution(client_df, "forecast_meter_rent_12m", axs[3])
plot_distribution(client_df, "forecast_price_energy_off_peak", axs[4])
plot_distribution(client_df, "forecast_price_energy_peak", axs[5])
plot_distribution(client_df, "forecast_price_pow_off_peak", axs[6])

# %% [markdown]
# # Price Dataset

# %%
#Count the occurrences of unique values in the "id" column and then count the frequency of those counts
price_df["id"].value_counts().value_counts()
# Out:
# 12    15990
# 11       83
# 10       11
# 9         6
# 8         3
# 7         3
# Name: id, dtype: int64

# %%
# Count the occurrences of unique values in the "price_date" column
price_df["price_date"].value_counts()
# Out:
# 2015-08-01    16094
# 2015-12-01    16094
# 2015-07-01    16090
# 2015-11-01    16087
# 2015-06-01    16085
# 2015-10-01    16085
# 2015-02-01    16082
# 2015-09-01    16082
# 2015-05-01    16080
# 2015-04-01    16079
# 2015-03-01    16074
# 2015-01-01    16070
# Name: price_date, dtype: int64

# %%
def plot_histogram_by_churn(dataframe, variable, figsize=(20, 5), bins=100, include_churn=True):
    """
    Plot histogram for a specific variable, optionally separated by churn status.
    """
    fig = plt.figure(figsize=figsize)
    
    if include_churn:
        ax = sns.histplot(data=dataframe, x=variable, bins=bins, hue='churn')
    else:
        ax = sns.histplot(data=dataframe, x=variable, bins=bins)

# Specify the attributes for which histograms will be plotted
attributes_to_plot = ['price_off_peak_var', 'price_peak_var', 'price_mid_peak_var',
                       'price_off_peak_fix', 'price_peak_fix', 'price_mid_peak_fix']

# Plot histograms for each specified attribute without considering churn status
for attribute in attributes_to_plot:
    plot_histogram_by_churn(dataframe=price_df, variable=attribute, include_churn=False)

# %% [markdown]
# Create histograms for the price features. Each feature's values are concentrated around certain points.
#
# Notably, there is a significant presence of zero values in both peak and mid-peak prices. However, off-peak prices exhibit very few occurrences of zero values. Consequently, the analysis of price sensitivity will focus exclusively on off-peak prices.

# %% [markdown]
# # Hypothesis Investigation

# %% [markdown]
# Now, let's assess customers' responsiveness to price changes. If an increase in prices results in customer churn, we can infer that these customers are sensitive to price. Conversely, if there is a decrease or no change in price and customers still switch, attributing their behavior to price sensitivity becomes challenging.
#
# Utilizing the consumption data for each company in the year 2015, we will introduce new features to quantify price sensitivity. These features will include averages over the entire year, the last 6 months, and the last 3 months.

# %%
#Generate mean average datasets
average_yearly = price_df.groupby(['id']).mean().reset_index()
average_last_6_months = price_df[price_df['price_date'] > '2015-06-01'].groupby(['id']).mean().reset_index()
average_last_3_months = price_df[price_df['price_date'] > '2015-10-01'].groupby(['id']).mean().reset_index()

#Display the head of the yearly mean dataset
average_yearly.head()
# Out:
#                                  id  price_off_peak_var  price_peak_var  \
# 0  0002203ffbb812588b632b9e628cc38d            0.124338        0.103794
# 1  0004351ebdd665e6ee664792efc4fd13            0.146426        0.000000
# 2  0010bcc39e42b3c2131ed2ce55246e3c            0.181558        0.000000
# 3  0010ee3855fdea87602a5b7aba8e42de            0.118757        0.098292
# 4  00114d74e963e47177db89bc70108537            0.147926        0.000000
#
#    price_mid_peak_var  price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# 0            0.073160           40.701732       24.421038           16.280694
# 1            0.000000           44.385450        0.000000            0.000000
# 2            0.000000           45.319710        0.000000            0.000000
# 3            0.069032           40.647427       24.388455           16.258971
# 4            0.000000           44.266930        0.000000            0.000000

# %%
#Rename columns for the yearly mean
average_yearly = average_yearly.rename(
columns={
"price_off_peak_var": "mean_year_price_off_peak_var",
"price_peak_var": "mean_year_price_peak_var",
"price_mid_peak_var": "mean_year_price_mid_peak_var",
"price_off_peak_fix": "mean_year_price_off_peak_fix",
"price_peak_fix": "mean_year_price_peak_fix",
"price_mid_peak_fix": "mean_year_price_mid_peak_fix"
}
)

average_yearly["mean_year_price_off_peak"] = average_yearly["mean_year_price_off_peak_var"] + average_yearly["mean_year_price_off_peak_fix"]
average_yearly["mean_year_price_peak"] = average_yearly["mean_year_price_peak_var"] + average_yearly["mean_year_price_peak_fix"]
average_yearly["mean_year_price_med_peak"] = average_yearly["mean_year_price_mid_peak_var"] + average_yearly["mean_year_price_mid_peak_fix"]

#Rename columns for the last 6 months mean
average_last_6_months = average_last_6_months.rename(
columns={
"price_off_peak_var": "mean_last_6_months_price_off_peak_var",
"price_peak_var": "mean_last_6_months_price_peak_var",
"price_mid_peak_var": "mean_last_6_months_price_mid_peak_var",
"price_off_peak_fix": "mean_last_6_months_price_off_peak_fix",
"price_peak_fix": "mean_last_6_months_price_peak_fix",
"price_mid_peak_fix": "mean_last_6_months_price_mid_peak_fix"
}
)

average_last_6_months["mean_last_6_months_price_off_peak"] = average_last_6_months["mean_last_6_months_price_off_peak_var"] + average_last_6_months["mean_last_6_months_price_off_peak_fix"]
average_last_6_months["mean_last_6_months_price_peak"] = average_last_6_months["mean_last_6_months_price_peak_var"] + average_last_6_months["mean_last_6_months_price_peak_fix"]
average_last_6_months["mean_last_6_months_price_med_peak"] = average_last_6_months["mean_last_6_months_price_mid_peak_var"] + average_last_6_months["mean_last_6_months_price_mid_peak_fix"]

#Rename columns for the last 3 months mean
average_last_3_months = average_last_3_months.rename(
columns={
"price_off_peak_var": "mean_last_3_months_price_off_peak_var",
"price_peak_var": "mean_last_3_months_price_peak_var",
"price_mid_peak_var": "mean_last_3_months_price_mid_peak_var",
"price_off_peak_fix": "mean_last_3_months_price_off_peak_fix",
"price_peak_fix": "mean_last_3_months_price_peak_fix",
"price_mid_peak_fix": "mean_last_3_months_price_mid_peak_fix"
}
)

average_last_3_months["mean_last_3_months_price_off_peak"] = average_last_3_months["mean_last_3_months_price_off_peak_var"] + average_last_3_months["mean_last_3_months_price_off_peak_fix"]
average_last_3_months["mean_last_3_months_price_peak"] = average_last_3_months["mean_last_3_months_price_peak_var"] + average_last_3_months["mean_last_3_months_price_peak_fix"]
average_last_3_months["mean_last_3_months_price_med_peak"] = average_last_3_months["mean_last_3_months_price_mid_peak_var"] + average_last_3_months["mean_last_3_months_price_mid_peak_fix"]

#Merge into one dataframe
price_features = pd.merge(average_yearly, average_last_6_months, on='id')
price_features = pd.merge(price_features, average_last_3_months, on='id')

#Display the head of the price features dataframe
price_features.head()
# Out:
#                                  id  mean_year_price_off_peak_var  \
# 0  0002203ffbb812588b632b9e628cc38d                      0.124338
# 1  0004351ebdd665e6ee664792efc4fd13                      0.146426
# 2  0010bcc39e42b3c2131ed2ce55246e3c                      0.181558
# 3  0010ee3855fdea87602a5b7aba8e42de                      0.118757
# 4  00114d74e963e47177db89bc70108537                      0.147926
#
#    mean_year_price_peak_var  mean_year_price_mid_peak_var  \
# 0                  0.103794                      0.073160
# 1                  0.000000                      0.000000
# 2                  0.000000                      0.000000
# 3                  0.098292                      0.069032
# 4                  0.000000                      0.000000
#
#    mean_year_price_off_peak_fix  mean_year_price_peak_fix  \
# 0                     40.701732                 24.421038
# 1                     44.385450                  0.000000
# ...

# %%
#Merge the price features with the churn information
price_churn_data = pd.merge(price_features, client_df[['id', 'churn']], on='id')

#Display the head of the merged dataframe
price_churn_data.head()
# Out:
#                                  id  mean_year_price_off_peak_var  \
# 0  0002203ffbb812588b632b9e628cc38d                      0.124338
# 1  0004351ebdd665e6ee664792efc4fd13                      0.146426
# 2  0010bcc39e42b3c2131ed2ce55246e3c                      0.181558
# 3  00114d74e963e47177db89bc70108537                      0.147926
# 4  0013f326a839a2f6ad87a1859952d227                      0.126076
#
#    mean_year_price_peak_var  mean_year_price_mid_peak_var  \
# 0                  0.103794                      0.073160
# 1                  0.000000                      0.000000
# 2                  0.000000                      0.000000
# 3                  0.000000                      0.000000
# 4                  0.105542                      0.074921
#
#    mean_year_price_off_peak_fix  mean_year_price_peak_fix  \
# 0                     40.701732                 24.421038
# 1                     44.385450                  0.000000
# ...

# %%
#Calculate correlation matrix
correlation_matrix = price_churn_data.corr()

#Plot the correlation heatmap
plt.figure(figsize=(20, 18))
sns.heatmap(correlation_matrix, xticklabels=correlation_matrix.columns.values, yticklabels=correlation_matrix.columns.values, cmap='Greens', annot=True, annot_kws={'size': 10})

#Set axis ticks size
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Display the heatmap
plt.show()

# %% [markdown]
# The preceding plot illustrates the correlation among price variables as well as their correlation with the churn variable. However, the correlation between churn and price variables appears to be minimal. This suggests that customers' churn is not significantly influenced by changes in pricing.
#
# Next, we will combine the client data with the price churn data for subsequent modeling steps.

# %%
#Merge client data without the 'churn' column with the price churn data
merged_churn_data = pd.merge(client_df.drop(columns=['churn']), price_churn_data, on='id')

#Display the head of the merged churn data
merged_churn_data.head()
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
# 3      1584             0                0  2010-03-30  2016-03-30
# 4      4425             0              526  2010-01-13  2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  \
# 0      2015-11-01   2015-06-23               0.00  ...
# ...

# %%
#Save the merged churn data to a CSV file
merged_churn_data.to_csv('churn_data_modeling.csv', index=False)
